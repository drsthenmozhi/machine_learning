# %%
import numpy as np 
import matplotlib.pyplot as plt 
from sklearn.datasets import make_circles 
from mpl_toolkits.mplot3d import Axes3D

# %%
X, Y = make_circles(n_samples = 500, noise = 0.02)

# %%
plt.scatter(X[:, 0], X[:, 1], c = Y, marker = '.') 
plt.show()

# %%
X1 = X[:, 0].reshape((-1, 1)) 
X2 = X[:, 1].reshape((-1, 1)) 
X3 = (X1**2 + X2**2) 
X = np.hstack((X, X3))

# %%
fig = plt.figure() 
axes = fig.add_subplot(111, projection = '3d') 
axes.scatter(X1, X2, X3, c = Y, depthshade = True) 
plt.show()

# %%
from sklearn import svm 
svc = svm.SVC(kernel = 'linear') 
svc.fit(X, Y) 
w = svc.coef_ 
b = svc.intercept_ 
svc.support_vectors_
# Out:
# array([[-0.94793511,  0.21937311,  0.94670554],
#        [-0.2810481 ,  0.92955796,  0.94306603],
#        [ 0.81474693, -0.49682483,  0.91064746],
#        [ 0.94190582,  0.21050301,  0.93149808],
#        [-0.10934682,  0.96605834,  0.94522544],
#        [ 0.57703863, -0.78423798,  0.94800279],
#        [ 0.65862106,  0.71734169,  0.94836081],
#        [-0.89005055,  0.32037378,  0.89482933],
#        [ 0.34264403, -0.8860999 ,  0.90257796],
#        [ 0.77547635,  0.5800986 ,  0.93787795],
#        [-0.41913757,  0.88326762,  0.95583799],
#        [-0.55305752, -0.7842652 ,  0.92094452],
#        [-0.82609482, -0.48447234,  0.91714609],
#        [-0.7419524 , -0.63337564,  0.95165807],
#        [-0.61394844, -0.7518258 ,  0.94217472],
#        [-0.67026752, -0.69807635,  0.93656914],
#        [-0.86830522, -0.39795373,  0.91232112],
#        [ 0.84904326, -0.43430867,  0.90949848],
#        [ 0.39852332, -0.89301501,  0.95629665],
#        [ 0.73236857,  0.60157628,  0.89825775],
#        [-0.85970848, -0.43425661,  0.92767747],
#        [ 0.85574532,  0.46086993,  0.94470114],
#        [ 0.87351538, -0.42054623,  0.93988826],
#        [-0.50427141, -0.83232421,  0.94705324],
#        [-0.89865788, -0.3797121 ,  0.95176727],
#        [ 0.75901955, -0.61459054,  0.95383222],
#        [ 0.21953846,  0.9420455 ,  0.93564686],
#        [-0.9511444 , -0.22935291,  0.95727842],
#        [ 0.96964739, -0.08676702,  0.94774458],
#        [ 0.44262088,  0.85997463,  0.93546961],
#        [ 0.13974461,  0.96729586,  0.95518984],
#        [ 0.24623181, -0.93218625,  0.92960132],
#        [-0.15648022, -0.83355006,  0.71929176],
#        [-0.20360603, -0.80189633,  0.68449313],
#        [-0.69750246, -0.47455307,  0.71171031],
#        [ 0.82429011,  0.03125331,  0.68043095],
#        [ 0.42024668, -0.71751755,  0.69143872],
#        [-0.79264632,  0.30900231,  0.72377061],
#        [ 0.64609033,  0.52754345,  0.69573481],
#        [-0.83762072,  0.04378464,  0.70352557],
#        [-0.83553297,  0.09156999,  0.70650041],
#        [ 0.42194701,  0.72251081,  0.70006115],
#        [-0.83453089,  0.05535827,  0.69950635],
#        [ 0.33032733, -0.77215883,  0.70534541],
#        [-0.82186462, -0.09024765,  0.68360609],
#        [ 0.19632302,  0.80322873,  0.68371913],
#        [ 0.83632593,  0.17099452,  0.72868019],
#        [ 0.33071928, -0.75858582,  0.68482769],
#        [ 0.82050626,  0.1251891 ,  0.68890283],
#        [-0.68706064, -0.48140051,  0.70379877],
#        [ 0.62871406,  0.54640582,  0.69384069],
#        [-0.57154332,  0.60409974,  0.69159827],
#        [ 0.77009417,  0.33063625,  0.70236536],
#        [ 0.35293168, -0.74804417,  0.68413086],
#        [ 0.60758343, -0.5769859 ,  0.70207035],
#        [-0.82451947,  0.026511  ,  0.6805352 ],
#        [-0.61029903,  0.5532738 ,  0.6785768 ],
#        [-0.81633983, -0.16945579,  0.69512598],
#        [ 0.73683494,  0.3668115 ,  0.6774764 ],
#        [-0.27371181, -0.7823824 ,  0.68704037],
#        [ 0.40232986, -0.72710277,  0.69054775],
#        [ 0.04998241,  0.82762891,  0.68746785],
#        [ 0.70073892, -0.47173693,  0.71357077]])

# %%
# plotting the separating hyperplane 
x1 = X[:,0].reshape((-1,1)) 
x2 = X[:,1].reshape((-1,1)) 
x1, x2 = np.meshgrid(x1, x2) 
x3 = -(w[0][0]*x1 + w[0][1]*x2 + b) / w[0][2]

# %%
fig = plt.figure() 
axes2 = fig.add_subplot(111, projection = '3d') 
axes2.scatter(X1, X2, X1**2 + X2**2, c = Y, depthshade = True) 
axes1 = fig.gca(projection = '3d') 
axes1.plot_surface(x1, x2, x3, alpha = 0.01) 
plt.show()

# %%
from mlxtend
